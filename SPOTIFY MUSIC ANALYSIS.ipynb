# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %%
df=pd.read_csv('Spotify-2000.csv')

# %%
df.head(20)
# Out:
#    Index                                  Title             Artist  \
# 0      1                                Sunrise        Norah Jones
# 1      2                            Black Night        Deep Purple
# 2      3                         Clint Eastwood           Gorillaz
# 3      4                          The Pretender       Foo Fighters
# 4      5                 Waitin' On A Sunny Day  Bruce Springsteen
# 5      6  The Road Ahead (Miles Of The Unknown)       City To City
# 6      7                      She Will Be Loved           Maroon 5
# 7      8                     Knights of Cydonia               Muse
# 8      9                         Mr. Brightside        The Killers
# 9     10                             Without Me             Eminem
# 10    11                         Love Me Tender      Elvis Presley
# 11    12                      Seven Nation Army  The White Stripes
# 12    13                          Als Het Golft            De Dijk
# ...

# %%
df.tail()
# Out:
#             Index            Title                    Artist        Top Genre  \
# 1990         1991        Hound Dog             Elvis Presley  adult standards
# 1991         1992  Johnny B. Goode               Chuck Berry       blues rock
# 1992         1993        Take Five  The Dave Brubeck Quartet            bebop
# 1993         1994   Blueberry Hill               Fats Domino  adult standards
# 1994  Fatboy Slim              NaN                       NaN              NaN
#
#         Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 1990  1958.0                   175.0    76.0          36.0           -8.0
# 1991  1959.0                   168.0    80.0          53.0           -9.0
# 1992  1959.0                   174.0    26.0          45.0          -13.0
# 1993  1959.0                   133.0    50.0          49.0          -10.0
# 1994     NaN                     NaN     NaN           NaN            NaN
#
# ...

# %%
df.shape
# Out:
# (1995, 15)

# %%
df.dtypes
# Out:
# Index                      object
# Title                      object
# Artist                     object
# Top Genre                  object
# Year                      float64
# Beats Per Minute (BPM)    float64
# Energy                    float64
# Danceability              float64
# Loudness (dB)             float64
# Liveness                  float64
# Valence                   float64
# Length (Duration)          object
# Acousticness              float64
# Speechiness               float64
# Popularity                float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Index                   Title                    Artist  \
# 0               1                 Sunrise               Norah Jones
# 1               2             Black Night               Deep Purple
# 2               3          Clint Eastwood                  Gorillaz
# 3               4           The Pretender              Foo Fighters
# 4               5  Waitin' On A Sunny Day         Bruce Springsteen
# ...           ...                     ...                       ...
# 1990         1991               Hound Dog             Elvis Presley
# 1991         1992         Johnny B. Goode               Chuck Berry
# 1992         1993               Take Five  The Dave Brubeck Quartet
# 1993         1994          Blueberry Hill               Fats Domino
# 1994  Fatboy Slim                     NaN                       NaN
#
#                 Top Genre    Year  Beats Per Minute (BPM)  Energy  \
# ...

# %%
df[df['Danceability'].isnull()]
# Out:
#             Index Title Artist Top Genre  Year  Beats Per Minute (BPM)  \
# 1994  Fatboy Slim   NaN    NaN       NaN   NaN                     NaN
#
#       Energy  Danceability  Loudness (dB)  Liveness  Valence  \
# 1994     NaN           NaN            NaN       NaN      NaN
#
#      Length (Duration)  Acousticness  Speechiness  Popularity
# 1994               NaN           NaN          NaN         NaN

# %%
sm = df['Danceability'].mean()

# %%
sm
# Out:
# 53.2382146439318

# %%
df['Danceability'].fillna(value=sm)
# Out:
# 0       53.000000
# 1       50.000000
# 2       66.000000
# 3       43.000000
# 4       58.000000
#           ...
# 1990    36.000000
# 1991    53.000000
# 1992    45.000000
# 1993    49.000000
# 1994    53.238215
# Name: Danceability, Length: 1995, dtype: float64

# %%
df['Danceability'].fillna(value=sm,inplace=True )

# %%
df['Danceability'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
sns.boxplot(data=df['Danceability'],orient='h')
plt.title('DANCEABILITY GRAPH')
plt.xlabel('VALUE')
plt.ylabel('PLOT')
# Out:
# Text(0, 0.5, 'PLOT')

# %%
small = df[['Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
       'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
       'Speechiness', 'Popularity']]
plt.figure(figsize=(10,4))
small.mean().plot.bar()
plt.title('Mean Values of Audio Features')
plt.show()
# Out:
# C:\Users\ANANDH~1\AppData\Local\Temp/ipykernel_17912/1315554537.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   small.mean().plot.bar()

# %%
features =  ['Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
       'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
       'Speechiness', 'Popularity']

for col in features:
  sns.displot(df, x=col, kde=True)
plt.figure(figsize=(20,20))
plt.show()

# %%
x=df['Danceability']
y=df['Beats Per Minute (BPM)']
plt.figure(figsize=(12,12))
plt.scatter(x,y, c='green')
plt.title('DANCEABILITY vs BEATS PER MINUTE SCATTER PLOT')
plt.xlabel('Danceability')
plt.ylabel('Beats Per Minute (BPM')
# Out:
# Text(0, 0.5, 'Beats Per Minute (BPM')

# %%
status=df['Top Genre'].value_counts()

# %%
status
# Out:
# album rock           412
# adult standards      123
# dutch pop             88
# alternative rock      86
# dance pop             83
#                     ...
# streektaal             1
# indie anthem-folk      1
# la pop                 1
# ccm                    1
# bebop                  1
# Name: Top Genre, Length: 149, dtype: int64

# %%
df.corr()
# Out:
#                             Year  Beats Per Minute (BPM)    Energy  \
# Year                    1.000000                0.012570  0.147235
# Beats Per Minute (BPM)  0.012570                1.000000  0.156644
# Energy                  0.147235                0.156644  1.000000
# Danceability            0.077493               -0.140602  0.139616
# Loudness (dB)           0.343764                0.092927  0.735711
# Liveness                0.019017                0.016256  0.174118
# Valence                -0.166163                0.059653  0.405175
# Acousticness           -0.132946               -0.122472 -0.665156
# Speechiness             0.054097                0.085598  0.205865
# Popularity             -0.158962               -0.003181  0.103393
#
#                         Danceability  Loudness (dB)  Liveness   Valence  \
# Year                        0.077493       0.343764  0.019017 -0.166163
# Beats Per Minute (BPM)     -0.140602       0.092927  0.016256  0.059653
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True )
# Out:
# <AxesSubplot:>

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(df.corr(), dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df.corr(), mask=mask, cmap=cmap, vmin=0, vmax=.5, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,20))
plt.title("Song Trends Over Time", fontsize=15)
sns.lineplot(x='Year', y='Loudness (dB)', data=df)
# Out:
# <AxesSubplot:title={'center':'Song Trends Over Time'}, xlabel='Year', ylabel='Loudness (dB)'>

# %%
df.Artist.nunique()
# Out:
# 730

# %%
val= df.Artist.value_counts()

# %%
val
# Out:
# Queen                 37
# The Beatles           36
# Coldplay              26
# U2                    26
# The Rolling Stones    24
#                       ..
# The Buoys              1
# New Order              1
# Limp Bizkit            1
# Snowy White            1
# Fats Domino            1
# Name: Artist, Length: 730, dtype: int64

# %%
# most popular songs
dfpop=df[df['Popularity']>=85]

# %%
dfpop.head(20)
# Out:
#      Index                            Title               Artist  \
# 522    523                       Wake Me Up               Avicii
# 529    530                        All of Me          John Legend
# 617    618       The Less I Know The Better          Tame Impala
# 683    684                          Perfect           Ed Sheeran
# 687    688                     Shape of You           Ed Sheeran
# 688    689                         Believer      Imagine Dragons
# 706    707                          Thunder      Imagine Dragons
# 726    727                          Shallow            Lady Gaga
# 745    746                       High Hopes  Panic! At The Disco
# 751    752                Someone You Loved        Lewis Capaldi
# 772    773        Havana (feat. Young Thug)       Camila Cabello
# 774    775         One Kiss (with Dua Lipa)        Calvin Harris
# 784    785                   Last Christmas                Wham!
# ...

# %%
dfpop.shape
# Out:
# (17, 15)

# %%
plt.rcParams["figure.figsize"] = (20,20)
sns.barplot(y =dfpop['Artist'],x =dfpop['Energy'], palette='rocket_r')
plt.title('Top 30 Artist heard')
plt.show()

# %%
max_songs= df.loc[df['Liveness'] > 40]
sns.barplot(y = max_songs['Artist'], x = max_songs['Liveness'], palette='viridis')
plt.rcParams["figure.figsize"] = (20,100)
plt.title('MOST Lively ARTISTS')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15)
g = sns.FacetGrid(dfpop,palette='mako')
g.map(sns.histplot, "Speechiness")
plt.show()

# %%
sns.countplot(data=dfpop, x='Popularity', hue='Title', palette = 'Set3')
plt.rcParams["figure.figsize"] = (20,20)
plt.show()

# %%
f, ax = plt.subplots(2,2, figsize=(16,24))

sns.scatterplot(x='Energy', y='Danceability',
                hue="Popularity", 
                palette="magma",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax[0][0])

sns.scatterplot(x="Valence", y="Danceability",
                hue="Popularity", 
                palette="cubehelix",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax[0][1])

sns.scatterplot(x="Danceability", y="Speechiness",
                hue="Popularity", 
                palette="binary",
                sizes=(1, 8), linewidth=0,
                 data=df, ax=ax[1][0])

sns.scatterplot(x="Loudness (dB)", y="Speechiness",
                hue="Popularity",
                palette="viridis",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax[1][1])
# Out:
# <AxesSubplot:xlabel='Loudness (dB)', ylabel='Speechiness'>

# %%
dfpop.shape
# Out:
# (17, 15)

# %%
dfpop.head()
# Out:
#     Index                       Title       Artist         Top Genre    Year  \
# 522   523                  Wake Me Up       Avicii          big room  2013.0
# 529   530                   All of Me  John Legend        neo mellow  2013.0
# 617   618  The Less I Know The Better  Tame Impala  australian psych  2015.0
# 683   684                     Perfect   Ed Sheeran               pop  2017.0
# 687   688                Shape of You   Ed Sheeran               pop  2017.0
#
#      Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 522                   124.0    78.0          53.0           -6.0      16.0
# 529                   120.0    26.0          42.0           -7.0      13.0
# 617                   117.0    74.0          64.0           -4.0      17.0
# 683                    95.0    45.0          60.0           -6.0      11.0
# 687                    96.0    65.0          83.0           -3.0       9.0
#
# ...

# %%
sns.barplot(data=df, x='Year', y='Speechiness', palette='coolwarm')
plt.xticks(rotation=90)
plt.show()

# %%
dfparty=df[df['Danceability']>= 80]

# %%
dfparty.shape
# Out:
# (84, 15)

# %%
newval = dfparty.Artist.value_counts()

# %%
newval
# Out:
# Michael Jackson                 10
# Eminem                           4
# Doe Maar                         4
# UB40                             3
# Bob Marley & The Wailers         3
# Queen                            2
# Prince                           2
# The Police                       2
# Stevie Wonder                    2
# Daft Punk                        2
# De Jeugd Van Tegenwoordig        1
# Genesis                          1
# Earth, Wind & Fire               1
# The Temptations                  1
# Earth & Fire                     1
# ABBA                             1
# The Alan Parsons Project         1
# The Proclaimers                  1
# Marvin Gaye                      1
# Survivor                         1
# Fleetwood Mac                    1
# House Of Pain                    1
# The Rolling Stones               1
# Gloria Gaynor                    1
# Tina Turner                      1
# Hans De Booij                    1
# Blackstreet                      1
# ...

# %%
plt.figure(figsize=(17,17))
sns.lineplot(x='Beats Per Minute (BPM)', y='Danceability', hue ='Artist', data=dfparty)
# Out:
# <AxesSubplot:xlabel='Beats Per Minute (BPM)', ylabel='Danceability'>

# %%
dfpop.plot(x="Danceability", y=["Loudness (dB)", "Liveness", "Energy"], kind='bar')
plt.figure(figsize=(30,30))

# %%
plt.figure(figsize=(20,20))
plt.title("Song Trends Over Time", fontsize=15)
sns.lineplot(x='Year', y='Energy',  data=df)
# Out:
# <AxesSubplot:title={'center':'Song Trends Over Time'}, xlabel='Year', ylabel='Energy'>

# %%
dfpartaay=df[df['Danceability']>= 90]

# %%
dfpartaay.shape
# Out:
# (17, 15)

# %%
x=dfpartaay['Danceability']
y=dfpartaay['Beats Per Minute (BPM)']
plt.figure(figsize=(20,20))
sns.lmplot('Danceability', 'Beats Per Minute (BPM)', data=dfpartaay, hue='Title', fit_reg=False)
plt.title('DANCEABILITY vs BEATS PER MINUTE SCATTER PLOT')
plt.xlabel('Danceability')
plt.ylabel('Beats Per Minute (BPM')
plt.show()
# Out:
# E:\CLG\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,20))
sns.lmplot('Danceability','Beats Per Minute (BPM)', data=dfparty, hue='Title', fit_reg=False)
plt.title('DANCEABILITY vs BEATS PER MINUTE SCATTER PLOT')
plt.xlabel('Danceability')
plt.ylabel('Beats Per Minute (BPM')
plt.show()
# Out:
# E:\CLG\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,20))
sns.lmplot('Energy', 'Popularity', data=dfparty, hue='Artist', palette='Spectral',fit_reg=False)
plt.title('Energy vs Popularity SCATTER PLOT')
plt.xlabel('energy')
plt.ylabel('popularity')
plt.show()
# Out:
# E:\CLG\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
